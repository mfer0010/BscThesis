# %%
# %reset

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


#Required by Jupyter for inlining images
# %matplotlib inline
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
data = pd.read_csv('../Data/LHC_bunches_B1.txt',sep=' ', header=None)
data.head(50)
# Out:
#                0       1
# 0   1.534476e+09    13.0
# 1   1.534476e+09   109.0
# 2   1.534476e+09   121.0
# 3   1.534476e+09   265.0
# 4   1.534477e+09   277.0
# 5   1.534477e+09   421.0
# 6   1.534477e+09   433.0
# 7   1.534477e+09   577.0
# 8   1.534477e+09    13.0
# 9   1.534477e+09   109.0
# 10  1.534477e+09   253.0
# 11  1.534478e+09   396.0
# 12  1.534478e+09   540.0
# 13  1.534478e+09   636.0
# 14  1.534478e+09   780.0
# 15  1.534478e+09   924.0
# 16  1.534478e+09  1068.0
# 17  1.534478e+09  1212.0
# 18  1.534478e+09  1308.0
# 19  1.534478e+09  1452.0
# 20  1.534479e+09  1596.0
# 21  1.534479e+09  1740.0
# 22  1.534479e+09  1884.0
# 23  1.534479e+09  1980.0
# 24  1.534479e+09  2124.0
# 25  1.534479e+09  2268.0
# 26  1.534479e+09  2412.0
# 27  1.534479e+09  2556.0
# 28  1.534479e+09  2556.0
# 29  1.534595e+09    13.0
# 30  1.534595e+09   109.0
# 31  1.534595e+09   120.0
# 32  1.534595e+09   132.0
# 33  1.534596e+09   144.0
# 34  1.534596e+09    13.0
# 35  1.534596e+09   109.0
# ...

# %%
data = data.rename(columns={0:'Time Stamp', 1:'Number of Bunches'})

# %% [markdown]
# Calculate Change in number of Bunches

# %%
### OLD Code ###

#change = []
#change.append(data['Number of Bunches'][0])
#for i in range(1,len(data['Number of Bunches'])):
#    change.append(data['Number of Bunches'][i]-data['Number of Bunches'][i-1])
#data ['Change'] = change

# %%
change = []
numberOfBunches = 0
for i in range (0,len(data['Number of Bunches'])):
    if data['Number of Bunches'][i] >= numberOfBunches:
        change.append(data['Number of Bunches'][i]-numberOfBunches)
    else:
        change.append(data['Number of Bunches'][i])
    numberOfBunches = data['Number of Bunches'][i]
data['Change']=change

# %%
fig = plt.figure()
plt.plot(data['Time Stamp'][:100],data['Number of Bunches'][:100])
plt.xlabel('Time Stamp')
plt.ylabel('Number of Bunches')
plt.title('Time Series of Number of Bunches in the LHC')
# Out:
# Text(0.5,1,'Time Series of Number of Bunches in the LHC')

# %%
fig = plt.figure()
plt.plot(data['Time Stamp'],data['Change'],'x')
plt.xlabel('Time Stamp')
plt.ylabel('Change in Number of Bunches')
plt.title('Time Series of Change in Number of Bunches in the LHC')
plt.savefig('../Dissertation/images/Number_of_Bunches')

# %%
data.head(30)
# Out:
#       Time Stamp  Number of Bunches  Change
# 0   1.534476e+09               13.0    13.0
# 1   1.534476e+09              109.0    96.0
# 2   1.534476e+09              121.0    12.0
# 3   1.534476e+09              265.0   144.0
# 4   1.534477e+09              277.0    12.0
# 5   1.534477e+09              421.0   144.0
# 6   1.534477e+09              433.0    12.0
# 7   1.534477e+09              577.0   144.0
# 8   1.534477e+09               13.0    13.0
# 9   1.534477e+09              109.0    96.0
# 10  1.534477e+09              253.0   144.0
# 11  1.534478e+09              396.0   143.0
# 12  1.534478e+09              540.0   144.0
# 13  1.534478e+09              636.0    96.0
# 14  1.534478e+09              780.0   144.0
# 15  1.534478e+09              924.0   144.0
# 16  1.534478e+09             1068.0   144.0
# 17  1.534478e+09             1212.0   144.0
# 18  1.534478e+09             1308.0    96.0
# 19  1.534478e+09             1452.0   144.0
# ...

# %%
data.describe()
# Out:
#          Time Stamp  Number of Bunches       Change
# count  1.467000e+03        1467.000000  1467.000000
# mean   1.537204e+09        1132.276755   114.149284
# std    1.656676e+06         818.494900    47.818083
# min    1.534476e+09           1.000000     0.000000
# 25%    1.535830e+09         396.000000    96.000000
# 50%    1.536954e+09        1068.000000   144.000000
# 75%    1.538572e+09        1884.000000   144.000000
# max    1.540021e+09        2556.000000   144.000000

# %% [markdown]
# As expected, the number of bunches increase with each injection

# %%
data.to_pickle('../Data/Beam1_Bunches.pkl')

# %% [markdown]
# #### Same thing for Beam 2

# %%
data = pd.read_csv('../Data/LHC_bunches_B2.txt',sep=' ', header=None)
data.head()
# Out:
#               0      1
# 0  1.534476e+09   13.0
# 1  1.534476e+09  109.0
# 2  1.534476e+09  121.0
# 3  1.534476e+09  133.0
# 4  1.534477e+09  145.0

# %%
data = data.rename(columns={0:'Time Stamp', 1:'Number of Bunches'})

# %%
## OLD CODE

#change = []
#change.append(data['Number of Bunches'][0])
#for i in range(1,len(data['Number of Bunches'])):
#    change.append(data['Number of Bunches'][i]-data['Number of Bunches'][i-1])
#data ['Change'] = change

# %%
change = []
numberOfBunches = 0
for i in range (0,len(data['Number of Bunches'])):
    if data['Number of Bunches'][i] >= numberOfBunches:
        change.append(data['Number of Bunches'][i]-numberOfBunches)
    else:
        change.append(data['Number of Bunches'][i])
    numberOfBunches = data['Number of Bunches'][i]
data['Change']=change

# %%
fig = plt.figure()
plt.plot(data['Time Stamp'],data['Number of Bunches'])
plt.xlabel('Time Stamp')
plt.ylabel('Number of Bunches')
plt.title('Time Series of Number of Bunches in the LHC')
# Out:
# Text(0.5,1,'Time Series of Number of Bunches in the LHC')

# %%
fig = plt.figure()
plt.plot(data['Time Stamp'],data['Change'],'x')
plt.xlabel('Time Stamp')
plt.ylabel('Change in Number of Bunches')
plt.title('Time Series of Change in Number of Bunches in the LHC')
# Out:
# Text(0.5,1,'Time Series of Change in Number of Bunches in the LHC')

# %%
data.to_pickle('../Data/Beam2_Bunches.pkl')
